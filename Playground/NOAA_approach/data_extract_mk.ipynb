# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2019/01001099999.csv')

# %%
df
# Out:
#         STATION        DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 0    1001099999  2019-01-01  70.933333  -8.666667        9.0
# 1    1001099999  2019-01-02  70.933333  -8.666667        9.0
# 2    1001099999  2019-01-03  70.933333  -8.666667        9.0
# 3    1001099999  2019-01-04  70.933333  -8.666667        9.0
# 4    1001099999  2019-01-05  70.933333  -8.666667        9.0
# ..          ...         ...        ...        ...        ...
# 360  1001099999  2019-12-27  70.933333  -8.666667        9.0
# 361  1001099999  2019-12-28  70.933333  -8.666667        9.0
# 362  1001099999  2019-12-29  70.933333  -8.666667        9.0
# 363  1001099999  2019-12-30  70.933333  -8.666667        9.0
# 364  1001099999  2019-12-31  70.933333  -8.666667        9.0
#
#                        NAME  TEMP  TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES  \
# 0    JAN MAYEN NOR NAVY, NO  24.0               24  15.5               24
# 1    JAN MAYEN NOR NAVY, NO  36.2               24  31.3               24
# ...

# %%
df2 = df[['DATE','TEMP']]
col = df['STATION'][1]
df2.rename(columns={"TEMP":str(col)})
# Out:
#            DATE  1001099999
# 0    2019-01-01        24.0
# 1    2019-01-02        36.2
# 2    2019-01-03        35.5
# 3    2019-01-04        35.8
# 4    2019-01-05        35.8
# ..          ...         ...
# 360  2019-12-27        32.5
# 361  2019-12-28        33.6
# 362  2019-12-29        27.7
# 363  2019-12-30        26.2
# 364  2019-12-31        27.3
#
# [365 rows x 2 columns]

# %%
l = pd.read_csv('weather_station_list.csv')
l
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-79ea23015729> in <module>
# ----> 1 l = pd.read_csv('weather_station_list.csv')
#       2 l
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
li = l['file_name'].to_list()
li
# Out:
# ['01001099999.csv',
#  '01001499999.csv',
#  '01002099999.csv',
#  '01003099999.csv',
#  '01006099999.csv',
#  '01007099999.csv',
#  '01008099999.csv',
#  '01009099999.csv',
#  '01010099999.csv',
#  '01011099999.csv',
#  '01015099999.csv',
#  '01016099999.csv',
#  '01017099999.csv',
#  '01020099999.csv',
#  '01023099999.csv',
#  '01024099999.csv',
#  '01025099999.csv',
#  '01026099999.csv',
#  '01027099999.csv',
#  '01028099999.csv',
#  '01030099999.csv',
#  '01033099999.csv',
#  '01035099999.csv',
#  '01036099999.csv',
#  '01037099999.csv',
#  '01042099999.csv',
#  '01043099999.csv',
#  '01044099999.csv',
#  '01045099999.csv',
#  '01046099999.csv',
#  '01047099999.csv',
#  '01049099999.csv',
#  '01052099999.csv',
#  '01055099999.csv',
#  '01058099999.csv',
#  '01059099999.csv',
#  '01062099999.csv',
#  '01065099999.csv',
#  '01068099999.csv',
#  '01074099999.csv',
#  '01076099999.csv',
#  '01078099999.csv',
#  '01082099999.csv',
#  '01083099999.csv',
#  '01084099999.csv',
# ...

# %%
li2 = li[0:3]
li2
# Out:
# ['01001099999.csv', '01001499999.csv', '01002099999.csv']

# %%
full_df = pd.DataFrame()
for station in li2:
    station_url = 'https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2019/' + station
    temp_df = pd.read_csv(station_url)
    df2 = temp_df[['DATE','TEMP']]
    # add max min and date
    print (df2)
    name = str(temp_df['STATION'][0])
    full_df.append(df2['TEMP'])

full_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0fa5b975a70c> in <module>
# ----> 1 full_df = pd.DataFrame()
#       2 for station in li2:
#       3     station_url = 'https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2019/' + station
#       4     temp_df = pd.read_csv(station_url)
#       5     df2 = temp_df[['DATE','TEMP']]
#
# NameError: name 'pd' is not defined

# %%
full_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
