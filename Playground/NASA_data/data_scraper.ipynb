# %% [markdown]
# # Web scrape Geotab data
# A tool to scrape data from the range calculator in Geotab's blog article: https://www.geotab.com/blog/ev-range/

# %% [markdown]
# Before running: `conda install beautifulsoup4 requests`

# %%
import json
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests

from bs4 import BeautifulSoup

# %%
# the url we are going to scrape
URL = "https://storage.googleapis.com/geotab_wfm_production_cms_storage/CMS-GeneralFiles-production/NA/EV/EVTOOL.html"

# %%
# get the content from the url
r = requests.get(URL)
# parse the html content
source = BeautifulSoup(r.content, "html.parser")

# %%
# keep scripts only
scripts = source.find_all("script")

# %%
# this is a list, and by simply looking at the raw string, we know we want the 1st (car info)
# and the 3rd (scale factors) element
scripts
# Out:
# [<script>
#      const EV_DATA = {
#          "Bmw i3 ": {
#              "2014": {
#                  "18.8": {
#                      "MMY": "Bmw i3 2014",
#                      "Make": "Bmw",
#                      "Model": "i3 ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "127.3235943",
#                      "Battery size (kwh) - at purchase": "18.8",
#                      "21C range (km)-original": "147.6552724",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "18.8": {
#                      "MMY": "Bmw i3 2015",
#                      "Make": "Bmw",
#                      "Model": "i3 ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "127.6417075",
#                      "Battery size (kwh) - at purchase": "18.8",
#                      "21C range (km)-original": "147.2872807",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "18.8": {
#                      "MMY": "Bmw i3 2016",
#                      "Make": "Bmw",
#                      "Model": "i3 ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "129.2027751",
#                      "Battery size (kwh) - at purchase": "18.8",
#                      "21C range (km)-original": "145.5077106",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "18.8": {
#                      "MMY": "Bmw i3 2017",
#                      "Make": "Bmw",
#                      "Model": "i3 ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "129.9230404",
#                      "Battery size (kwh) - at purchase": "18.8",
#                      "21C range (km)-original": "144.7010472",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "27.2": {
#                      "MMY": "Bmw i3 2018",
#                      "Make": "Bmw",
#                      "Model": "i3 ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "134.467512",
#                      "Battery size (kwh) - at purchase": "27.2",
#                      "21C range (km)-original": "202.2793431",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "33.2": {
#                      "MMY": "Bmw i3 2019",
#                      "Make": "Bmw",
#                      "Model": "i3 ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "135.54",
#                      "Battery size (kwh) - at purchase": "33.2",
#                      "21C range (km)-original": "245",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Chevrolet Bolt ": {
#              "2017": {
#                  "58.5": {
#                      "MMY": "Chevrolet Bolt EV 2017",
#                      "Make": "Chevrolet",
#                      "Model": "Bolt ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "137.6924794",
#                      "Battery size (kwh) - at purchase": "58.5",
#                      "21C range (km)-original": "424.8598055",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "58.5": {
#                      "MMY": "Chevrolet Bolt EV 2018",
#                      "Make": "Chevrolet",
#                      "Model": "Bolt ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "146.1701719",
#                      "Battery size (kwh) - at purchase": "58.5",
#                      "21C range (km)-original": "400.2184524",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "60": {
#                      "MMY": "Chevrolet Bolt EV 2019",
#                      "Make": "Chevrolet",
#                      "Model": "Bolt ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "142.94",
#                      "Battery size (kwh) - at purchase": "60",
#                      "21C range (km)-original": "420",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Chevrolet Spark ": {
#              "2014": {
#                  "19.264": {
#                      "MMY": "Chevrolet Spark EV 2014",
#                      "Make": "Chevrolet",
#                      "Model": "Spark ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "132.8425441",
#                      "Battery size (kwh) - at purchase": "19.264",
#                      "21C range (km)-original": "145.0137841",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "17.1": {
#                      "MMY": "Chevrolet Spark EV 2015",
#                      "Make": "Chevrolet",
#                      "Model": "Spark ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "130.1233381",
#                      "Battery size (kwh) - at purchase": "17.1",
#                      "21C range (km)-original": "131.4137821",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "17.1": {
#                      "MMY": "Chevrolet Spark EV 2016",
#                      "Make": "Chevrolet",
#                      "Model": "Spark ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "133.5538043",
#                      "Battery size (kwh) - at purchase": "17.1",
#                      "21C range (km)-original": "128.0382846",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Coda Sedan ": {
#              "2012": {
#                  "33.8": {
#                      "MMY": "Coda Sedan 2012",
#                      "Make": "Coda",
#                      "Model": "Sedan ",
#                      "Trim details": "",
#                      "Year": "2012",
#                      "Median peak fuel efficieny (21C) wh/km": "178.5268414",
#                      "Battery size (kwh) - at purchase": "33.8",
#                      "21C range (km)-original": "189.3272727",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Fiat 500e ": {
#              "2013": {
#                  "22.8": {
#                      "MMY": "Fiat 500e 2013",
#                      "Make": "Fiat",
#                      "Model": "500e ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "153.363373",
#                      "Battery size (kwh) - at purchase": "22.8",
#                      "21C range (km)-original": "148.6665268",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "22.8": {
#                      "MMY": "Fiat 500e 2014",
#                      "Make": "Fiat",
#                      "Model": "500e ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "146.926738",
#                      "Battery size (kwh) - at purchase": "22.8",
#                      "21C range (km)-original": "155.1793793",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "22.8": {
#                      "MMY": "Fiat 500e 2015",
#                      "Make": "Fiat",
#                      "Model": "500e ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "143.6239311",
#                      "Battery size (kwh) - at purchase": "22.8",
#                      "21C range (km)-original": "158.7479177",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "22.8": {
#                      "MMY": "Fiat 500e 2016",
#                      "Make": "Fiat",
#                      "Model": "500e ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "147.1821306",
#                      "Battery size (kwh) - at purchase": "22.8",
#                      "21C range (km)-original": "154.9101097",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Ford Focus ": {
#              "2012": {
#                  "17.5": {
#                      "MMY": "Ford Focus EV 2012",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2012",
#                      "Median peak fuel efficieny (21C) wh/km": "152.3550304",
#                      "Battery size (kwh) - at purchase": "17.5",
#                      "21C range (km)-original": "114.8632898",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2013": {
#                  "17.5": {
#                      "MMY": "Ford Focus EV 2013",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "160.262305",
#                      "Battery size (kwh) - at purchase": "17.5",
#                      "21C range (km)-original": "109.1959834",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "17.5": {
#                      "MMY": "Ford Focus EV 2014",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "160.5836922",
#                      "Battery size (kwh) - at purchase": "17.5",
#                      "21C range (km)-original": "108.977442",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "17.5": {
#                      "MMY": "Ford Focus EV 2015",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "162.2749171",
#                      "Battery size (kwh) - at purchase": "17.5",
#                      "21C range (km)-original": "107.841682",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "17.5": {
#                      "MMY": "Ford Focus EV 2016",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "146.9213227",
#                      "Battery size (kwh) - at purchase": "17.5",
#                      "21C range (km)-original": "119.1113698",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "28.5": {
#                      "MMY": "Ford Focus EV 2017",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "151.0728067",
#                      "Battery size (kwh) - at purchase": "28.5",
#                      "21C range (km)-original": "188.6507613",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "28.5": {
#                      "MMY": "Ford Focus EV 2018",
#                      "Make": "Ford",
#                      "Model": "Focus ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "160.5608608",
#                      "Battery size (kwh) - at purchase": "28.5",
#                      "21C range (km)-original": "177.5027852",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Honda Fit ": {
#              "2013": {
#                  "18": {
#                      "MMY": "Honda Fit EV 2013",
#                      "Make": "Honda",
#                      "Model": "Fit ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "139.8272225",
#                      "Battery size (kwh) - at purchase": "18",
#                      "21C range (km)-original": "128.7302978",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "18": {
#                      "MMY": "Honda Fit EV 2014",
#                      "Make": "Honda",
#                      "Model": "Fit ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "115.9768782",
#                      "Battery size (kwh) - at purchase": "18",
#                      "21C range (km)-original": "155.2033499",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Hyundai Ioniq Electric ": {
#              "2017": {
#                  "28": {
#                      "MMY": "Hyundai Ioniq Electric 2017",
#                      "Make": "Hyundai",
#                      "Model": "Ioniq Electric ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "121.4086652",
#                      "Battery size (kwh) - at purchase": "28",
#                      "21C range (km)-original": "230.6260426",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "28": {
#                      "MMY": "Hyundai Ioniq Electric 2018",
#                      "Make": "Hyundai",
#                      "Model": "Ioniq Electric ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "121.6886751",
#                      "Battery size (kwh) - at purchase": "28",
#                      "21C range (km)-original": "230.095364",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "28": {
#                      "MMY": "Hyundai Ioniq Electric 2019",
#                      "Make": "Hyundai",
#                      "Model": "Ioniq Electric ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "117.03",
#                      "Battery size (kwh) - at purchase": "28",
#                      "21C range (km)-original": "239",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Hyundai Kona ": {
#              "2019": {
#                  "64": {
#                      "MMY": "Hyundai Kona EV 2019",
#                      "Make": "Hyundai",
#                      "Model": "Kona ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "130.32",
#                      "Battery size (kwh) - at purchase": "64",
#                      "21C range (km)-original": "491",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Kia Soul ": {
#              "2015": {
#                  "27": {
#                      "MMY": "Kia Soul EV 2015",
#                      "Make": "Kia",
#                      "Model": "Soul ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "141.7903449",
#                      "Battery size (kwh) - at purchase": "27",
#                      "21C range (km)-original": "190.4219926",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "27": {
#                      "MMY": "Kia Soul EV 2017",
#                      "Make": "Kia",
#                      "Model": "Soul ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "138.977368",
#                      "Battery size (kwh) - at purchase": "27",
#                      "21C range (km)-original": "194.2762364",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "30": {
#                      "MMY": "Kia Soul EV 2018",
#                      "Make": "Kia",
#                      "Model": "Soul ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "132.6144831",
#                      "Battery size (kwh) - at purchase": "30",
#                      "21C range (km)-original": "226.2196352",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "30": {
#                      "MMY": "Kia Soul EV 2019",
#                      "Make": "Kia",
#                      "Model": "Soul ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "131.51",
#                      "Battery size (kwh) - at purchase": "30",
#                      "21C range (km)-original": "228",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2020": {
#                  "64": {
#                      "MMY": "Kia Soul EV 2020",
#                      "Make": "Kia",
#                      "Model": "Soul ",
#                      "Trim details": "",
#                      "Year": "2020",
#                      "Median peak fuel efficieny (21C) wh/km": "133.0668253",
#                      "Battery size (kwh) - at purchase": "64",
#                      "21C range (km)-original": "480.9613504",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Mercedes-Benz B-Class ": {
#              "2017": {
#                  "28": {
#                      "MMY": "Mercedes-Benz B-Class EV 2017",
#                      "Make": "Mercedes-Benz",
#                      "Model": "B-Class ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "227.2327931",
#                      "Battery size (kwh) - at purchase": "28",
#                      "21C range (km)-original": "123.2216513",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "28": {
#                      "MMY": "Mercedes-Benz B-Class EV 2018",
#                      "Make": "Mercedes-Benz",
#                      "Model": "B-Class ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "193.4836258",
#                      "Battery size (kwh) - at purchase": "28",
#                      "21C range (km)-original": "144.7150883",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Mitsubishi iMiEV ": {
#              "2012": {
#                  "13.5": {
#                      "MMY": "Mitsubishi iMiEV 2013",
#                      "Make": "Mitsubishi",
#                      "Model": "iMiEV ",
#                      "Trim details": "",
#                      "Year": "2012",
#                      "Median peak fuel efficieny (21C) wh/km": "128.6818415",
#                      "Battery size (kwh) - at purchase": "13.5",
#                      "21C range (km)-original": "104.9099068",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2013": {
#                  "13.5": {
#                      "MMY": "Mitsubishi iMiEV 2013",
#                      "Make": "Mitsubishi",
#                      "Model": "iMiEV ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "128.7018756",
#                      "Battery size (kwh) - at purchase": "13.5",
#                      "21C range (km)-original": "104.8935762",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "13.5": {
#                      "MMY": "Mitsubishi iMiEV 2014",
#                      "Make": "Mitsubishi",
#                      "Model": "iMiEV ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "137.2042068",
#                      "Battery size (kwh) - at purchase": "13.5",
#                      "21C range (km)-original": "98.39348451",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "13.5": {
#                      "MMY": "Mitsubishi iMiEV 2016",
#                      "Make": "Mitsubishi",
#                      "Model": "iMiEV ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "134.9031711",
#                      "Battery size (kwh) - at purchase": "13.5",
#                      "21C range (km)-original": "100.0717766",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "13.5": {
#                      "MMY": "Mitsubishi iMiEV 2017",
#                      "Make": "Mitsubishi",
#                      "Model": "iMiEV ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "130.1907683",
#                      "Battery size (kwh) - at purchase": "13.5",
#                      "21C range (km)-original": "103.6939883",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Nissan eNV200 ": {
#              "2019": {
#                  "40": {
#                      "MMY": "Nissan eNV200 2019",
#                      "Make": "Nissan",
#                      "Model": "eNV200 ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "209.96",
#                      "Battery size (kwh) - at purchase": "40",
#                      "21C range (km)-original": "191",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Nissan Leaf ": {
#              "2010": {
#                  "21.3": {
#                      "MMY": "Nissan Leaf 2010",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2010",
#                      "Median peak fuel efficieny (21C) wh/km": "146.4847458",
#                      "Battery size (kwh) - at purchase": "21.3",
#                      "21C range (km)-original": "145.407632",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2011": {
#                  "21.3": {
#                      "MMY": "Nissan Leaf 2011",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2011",
#                      "Median peak fuel efficieny (21C) wh/km": "162.2236367",
#                      "Battery size (kwh) - at purchase": "21.3",
#                      "21C range (km)-original": "131.300225",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2012": {
#                  "21.3": {
#                      "MMY": "Nissan Leaf 2012",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2012",
#                      "Median peak fuel efficieny (21C) wh/km": "153.5012337",
#                      "Battery size (kwh) - at purchase": "21.3",
#                      "21C range (km)-original": "138.7610997",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2013": {
#                  "21.3": {
#                      "MMY": "Nissan Leaf 2013",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "144.9034982",
#                      "Battery size (kwh) - at purchase": "21.3",
#                      "21C range (km)-original": "146.9943809",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "21.3": {
#                      "MMY": "Nissan Leaf 2014",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "136.3520604",
#                      "Battery size (kwh) - at purchase": "21.3",
#                      "21C range (km)-original": "156.213261",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "21.3": {
#                      "MMY": "Nissan Leaf 2015",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "139.0508684",
#                      "Battery size (kwh) - at purchase": "21.3",
#                      "21C range (km)-original": "153.1813518",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "28.5": {
#                      "MMY": "Nissan Leaf 2017",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "141.3708835",
#                      "Battery size (kwh) - at purchase": "28.5",
#                      "21C range (km)-original": "201.597382",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "38": {
#                      "MMY": "Nissan Leaf 2018",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "151.3785249",
#                      "Battery size (kwh) - at purchase": "38",
#                      "21C range (km)-original": "251.0263595",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "40": {
#                      "MMY": "Nissan Leaf 2019",
#                      "Make": "Nissan",
#                      "Model": "Leaf ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "155.64",
#                      "Battery size (kwh) - at purchase": "40",
#                      "21C range (km)-original": "257",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Renault Zoe ": {
#              "2013": {
#                  "22": {
#                      "MMY": "Renault Zoe 2013",
#                      "Make": "Renault",
#                      "Model": "Zoe ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "150.4218795",
#                      "Battery size (kwh) - at purchase": "22",
#                      "21C range (km)-original": "146.2553191",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "22": {
#                      "MMY": "Renault Zoe 2014",
#                      "Make": "Renault",
#                      "Model": "Zoe ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "152.2132759",
#                      "Battery size (kwh) - at purchase": "22",
#                      "21C range (km)-original": "144.534042",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "40": {
#                      "MMY": "Renault Zoe 2016",
#                      "Make": "Renault",
#                      "Model": "Zoe ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "144.227245",
#                      "Battery size (kwh) - at purchase": "40",
#                      "21C range (km)-original": "277.3401101",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "41": {
#                      "MMY": "Renault Zoe 2019",
#                      "Make": "Renault",
#                      "Model": "Zoe ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "135.08",
#                      "Battery size (kwh) - at purchase": "41",
#                      "21C range (km)-original": "304",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Renault Kangoo Z.E. ": {
#              "2019": {
#                  "33": {
#                      "MMY": "Renault Kangoo Z.E. 2019",
#                      "Make": "Renault",
#                      "Model": "Kangoo Z.E. ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "157.17",
#                      "Battery size (kwh) - at purchase": "33",
#                      "21C range (km)-original": "210",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Smart For Two Electric Drive ": {
#              "2013": {
#                  "16.5": {
#                      "MMY": "Smart Fortwo 2013",
#                      "Make": "Smart",
#                      "Model": "For Two Electric Drive ",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "130.9768938",
#                      "Battery size (kwh) - at purchase": "16.5",
#                      "21C range (km)-original": "125.9764186",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "16.5": {
#                      "MMY": "Smart Fortwo 2014",
#                      "Make": "Smart",
#                      "Model": "For Two Electric Drive ",
#                      "Trim details": "",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "123.6669363",
#                      "Battery size (kwh) - at purchase": "16.5",
#                      "21C range (km)-original": "133.4228897",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "16.5": {
#                      "MMY": "Smart Fortwo 2015",
#                      "Make": "Smart",
#                      "Model": "For Two Electric Drive ",
#                      "Trim details": "",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "131.8315586",
#                      "Battery size (kwh) - at purchase": "16.5",
#                      "21C range (km)-original": "125.1597127",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "16.5": {
#                      "MMY": "Smart Fortwo 2016",
#                      "Make": "Smart",
#                      "Model": "For Two Electric Drive ",
#                      "Trim details": "",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "122.9829928",
#                      "Battery size (kwh) - at purchase": "16.5",
#                      "21C range (km)-original": "134.1648925",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "16.5": {
#                      "MMY": "Smart Fortwo 2017",
#                      "Make": "Smart",
#                      "Model": "For Two Electric Drive ",
#                      "Trim details": "",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "128.849589",
#                      "Battery size (kwh) - at purchase": "16.5",
#                      "21C range (km)-original": "128.0562874",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "16.5": {
#                      "MMY": "Smart Fortwo 2018",
#                      "Make": "Smart",
#                      "Model": "For Two Electric Drive ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "132.2204016",
#                      "Battery size (kwh) - at purchase": "16.5",
#                      "21C range (km)-original": "124.7916343",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Tesla Model S": {
#              "2012": {
#                  "75": {
#                      "MMY": "Tesla Model S 2012 (75 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (75 kwh usable battery size)",
#                      "Year": "2012",
#                      "Median peak fuel efficieny (21C) wh/km": "207.2875244",
#                      "Battery size (kwh) - at purchase": "75",
#                      "21C range (km)-original": "361.8162753",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2013": {
#                  "75": {
#                      "MMY": "Tesla Model S 2013 (75 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (75 kwh usable battery size)",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "202.632349",
#                      "Battery size (kwh) - at purchase": "75",
#                      "21C range (km)-original": "370.1284635",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "75": {
#                      "MMY": "Tesla Model S 2014 (75 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (75 kwh usable battery size)",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "203.72856",
#                      "Battery size (kwh) - at purchase": "75",
#                      "21C range (km)-original": "368.1368974",
#                      "Powertrain": "EV"
#                  },
#                  "58.5": {
#                      "MMY": "Tesla Model S 2014 (58.5 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (58.5 kwh usable battery size)",
#                      "Year": "2014",
#                      "Median peak fuel efficieny (21C) wh/km": "203.72856",
#                      "Battery size (kwh) - at purchase": "58.5",
#                      "21C range (km)-original": "287.14678",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2015": {
#                  "75": {
#                      "MMY": "Tesla Model S 2015 (75 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (75 kwh usable battery size)",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "201.7940106",
#                      "Battery size (kwh) - at purchase": "75",
#                      "21C range (km)-original": "371.6661351",
#                      "Powertrain": "EV"
#                  },
#                  "58.5": {
#                      "MMY": "Tesla Model S 2015 (58.5 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (58.5 kwh usable battery size)",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "201.7940106",
#                      "Battery size (kwh) - at purchase": "58.5",
#                      "21C range (km)-original": "289.8995854",
#                      "Powertrain": "EV"
#                  },
#                  "68.8": {
#                      "MMY": "Tesla Model S 2015 (68.8 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (68.8 kwh usable battery size)",
#                      "Year": "2015",
#                      "Median peak fuel efficieny (21C) wh/km": "201.7940106",
#                      "Battery size (kwh) - at purchase": "68.8",
#                      "21C range (km)-original": "340.9417346",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2016": {
#                  "65.9": {
#                      "MMY": "Tesla Model S 2016 (65.9 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (65.9 kwh usable battery size)",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "199.2625664",
#                      "Battery size (kwh) - at purchase": "65.9",
#                      "21C range (km)-original": "330.719418",
#                      "Powertrain": "EV"
#                  },
#                  "62.4": {
#                      "MMY": "Tesla Model S 2016 (62.4 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (62.4 kwh usable battery size)",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "199.2625664",
#                      "Battery size (kwh) - at purchase": "62.4",
#                      "21C range (km)-original": "313.1546538",
#                      "Powertrain": "EV"
#                  },
#                  "72.6": {
#                      "MMY": "Tesla Model S 2016 (72.6 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (72.6 kwh usable battery size)",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "199.2625664",
#                      "Battery size (kwh) - at purchase": "72.6",
#                      "21C range (km)-original": "364.3433953",
#                      "Powertrain": "EV"
#                  },
#                  "81.8": {
#                      "MMY": "Tesla Model S 2016 (81.8 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (81.8 kwh usable battery size)",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "199.2625664",
#                      "Battery size (kwh) - at purchase": "81.8",
#                      "21C range (km)-original": "410.5136327",
#                      "Powertrain": "EV"
#                  },
#                  "98.4": {
#                      "MMY": "Tesla Model S 2016 (98.4 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (98.4 kwh usable battery size)",
#                      "Year": "2016",
#                      "Median peak fuel efficieny (21C) wh/km": "199.2625664",
#                      "Battery size (kwh) - at purchase": "98.4",
#                      "21C range (km)-original": "493.8208002",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2017": {
#                  "98.4": {
#                      "MMY": "Tesla Model S 2017 (98.4 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (98.4 kwh usable battery size)",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "197.5636601",
#                      "Battery size (kwh) - at purchase": "98.4",
#                      "21C range (km)-original": "498.0673063",
#                      "Powertrain": "EV"
#                  },
#                  "62.4": {
#                      "MMY": "Tesla Model S 2017 (62.4 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (62.4 kwh usable battery size)",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "197.5636601",
#                      "Battery size (kwh) - at purchase": "62.4",
#                      "21C range (km)-original": "315.8475601",
#                      "Powertrain": "EV"
#                  },
#                  "72.6": {
#                      "MMY": "Tesla Model S 2017 (72.6 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (72.6 kwh usable battery size)",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "197.5636601",
#                      "Battery size (kwh) - at purchase": "72.6",
#                      "21C range (km)-original": "367.4764882",
#                      "Powertrain": "EV"
#                  },
#                  "81.8": {
#                      "MMY": "Tesla Model S 2017 (81.8 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (81.8 kwh usable battery size)",
#                      "Year": "2017",
#                      "Median peak fuel efficieny (21C) wh/km": "197.5636601",
#                      "Battery size (kwh) - at purchase": "81.8",
#                      "21C range (km)-original": "414.0437566",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2018": {
#                  "72.6": {
#                      "MMY": "Tesla Model S 2018 (72.6 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (72.6 kwh usable battery size)",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "200.6114966",
#                      "Battery size (kwh) - at purchase": "72.6",
#                      "21C range (km)-original": "361.8935168",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "72.6": {
#                      "MMY": "Tesla Model S 2019 (72.6 kwh usable battery size)",
#                      "Make": "Tesla",
#                      "Model": "Model S",
#                      "Trim details": "Model S (72.6 kwh usable battery size)",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "205.1253131",
#                      "Battery size (kwh) - at purchase": "72.6",
#                      "21C range (km)-original": "353.9299899",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Tesla Model 3 ": {
#              "2018": {
#                  "54": {
#                      "MMY": "Tesla Model 3 2018",
#                      "Make": "Tesla",
#                      "Model": "Model 3 ",
#                      "Trim details": "",
#                      "Year": "2018",
#                      "Median peak fuel efficieny (21C) wh/km": "157.6561135",
#                      "Battery size (kwh) - at purchase": "54",
#                      "21C range (km)-original": "342.5176404",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2019": {
#                  "54": {
#                      "MMY": "Tesla Model 3 2019",
#                      "Make": "Tesla",
#                      "Model": "Model 3 ",
#                      "Trim details": "",
#                      "Year": "2019",
#                      "Median peak fuel efficieny (21C) wh/km": "152.44",
#                      "Battery size (kwh) - at purchase": "54",
#                      "21C range (km)-original": "354",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Think City ": {
#              "2011": {
#                  "24": {
#                      "MMY": "Think City 2011",
#                      "Make": "Think",
#                      "Model": "City ",
#                      "Trim details": "",
#                      "Year": "2011",
#                      "Median peak fuel efficieny (21C) wh/km": "157.0496905",
#                      "Battery size (kwh) - at purchase": "24",
#                      "21C range (km)-original": "152.8178752",
#                      "Powertrain": "EV"
#                  }
#              }
#          },
#          "Toyota RAV4": {
#              "2012": {
#                  "40": {
#                      "MMY": "Toyota RAV4EV 2012",
#                      "Make": "Toyota",
#                      "Model": "RAV4",
#                      "Trim details": "",
#                      "Year": "2012",
#                      "Median peak fuel efficieny (21C) wh/km": "170.8931568",
#                      "Battery size (kwh) - at purchase": "40",
#                      "21C range (km)-original": "234.0643753",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2013": {
#                  "40": {
#                      "MMY": "Toyota RAV4EV 2013",
#                      "Make": "Toyota",
#                      "Model": "RAV4",
#                      "Trim details": "",
#                      "Year": "2013",
#                      "Median peak fuel efficieny (21C) wh/km": "167.3762963",
#                      "Battery size (kwh) - at purchase": "40",
#                      "21C range (km)-original": "238.9824658",
#                      "Powertrain": "EV"
#                  }
#              },
#              "2014": {
#                  "40": {
#                      "MMY": "Toyota RAV4EV 2014",
#                      "Make": "Toyota",
#                      "Model": "RAV4",
#                      "Trim details": "",
# ...
#              Math.round(selectedTemperatureObj.Temp)
#          setTemperatureInDragbar(currentTemp);
#      }
#
#      function makeModelSelected() {
#          toggleSVGOpacity(true);
#          const selectedMakeModel = document.querySelector('.MakeModelSelectContainer select');
#          const makeModelValue = selectedMakeModel.options[selectedMakeModel.selectedIndex].value;
#          if (makeModelValue.startsWith('Tesla') &&
#              (+selectedTemperatureObj.Temp > +EVTool_SETTINGS.teslaHighestTemp
#                  || +selectedTemperatureObj.Temp < +EVTool_SETTINGS.teslaLowestTemp)) {
#              setTempToTeslaBoundary();
#          }
#
#          resetSelection('Year', 'YearSelectContainer');
#          resetSelection('Battery Size', 'BatterySizeSelectContainer');
#
#          for (let year in evCarData[makeModelValue]) {
#              const yearOption = document.createElement('option');
#              yearOption.value = year;
#              yearOption.innerHTML = year;
#              document.querySelector('.YearSelectContainer select').appendChild(yearOption);
#          }
#      }
#
#      function yearSelected() {
#          toggleSVGOpacity(true);
#          const selectedMakeModel = document.querySelector('.MakeModelSelectContainer select');
#          const makeModelValue = selectedMakeModel.options[selectedMakeModel.selectedIndex].value;
#
#          const selectedYear = document.querySelector('.YearSelectContainer select');
#          const yearValue = selectedYear.options[selectedYear.selectedIndex].value;
#
#          resetSelection('Battery Size', 'BatterySizeSelectContainer');
#
#          for (let batterySize in evCarData[makeModelValue][yearValue]) {
#              const batterySizeOption = document.createElement('option');
#              let batteryDropDownValue = batterySize;
#              batterySizeOption.name = batterySize;
#              batterySizeOption.value = batteryDropDownValue;
#              batterySizeOption.innerHTML = `${batteryDropDownValue} (kWh)`;
#              document.querySelector('.BatterySizeSelectContainer select').appendChild(batterySizeOption);
#          }
#      }
#
#      function batterySizeSelected() {
#          const selectedMakeModel = document.querySelector('.MakeModelSelectContainer select');
#          const makeModelValue = selectedMakeModel.options[selectedMakeModel.selectedIndex].value;
#
#          const selectedYear = document.querySelector('.YearSelectContainer select');
#          const yearValue = selectedYear.options[selectedYear.selectedIndex].value;
#
#          const selectedBattery = document.querySelector('.BatterySizeSelectContainer select');
#
#          const batterySizeName = selectedBattery.options[selectedBattery.selectedIndex].name;
#
#          selectedCar = evCarData[makeModelValue][yearValue][batterySizeName];
#
#          toggleSVGOpacity(false);
#          updateRangeWidth();
#          updateVariables();
#      }
#
#      function onMetricChange() {
#          EVTool_SETTINGS.isImperial = !EVTool_SETTINGS.isImperial;
#          let tempMetricValue;
#          if (EVTool_SETTINGS.isImperial) {
#              tempMetricValue = 'F';
#              document.getElementById('Metric').style.color = 'lightgray';
#              document.getElementById('Imperial').style.color = '#2196F3';
#          } else {
#              tempMetricValue = 'C';
#              document.getElementById('Metric').style.color = 'rgb(45, 85, 160)';
#              document.getElementById('Imperial').style.color = 'lightgray';
#          }
#
#          const baseline = document.getElementById('baseline-0-degrees');
#          const optimalLine = document.getElementById('baseline-21-degrees');
#          baseline.textContent = `${tempMetricValue === 'F' ? celciusToFarenheight(0) : 0} °${tempMetricValue}`;
#          optimalLine.textContent = `${tempMetricValue === 'F' ? Math.round(celciusToFarenheight(21)) : 21} °${tempMetricValue}`;
#
#          const dragBarMetric = document.querySelectorAll('#var1-container text')[1];
#          dragBarMetric.textContent = `°${tempMetricValue}`;
#
#          updateVariables();
#      }
#
#      function toggleMoveDragBar(event, manuallySet) {
#          event.preventDefault();
#          mouseMove = manuallySet;
#      }
#
#      function moveDragBar(event) {
#          event.preventDefault();
#          const cursorX = event.clientX || event.touches[0].clientX;
#          const cursorY = event.clientY || event.touches[0].clientY;
#
#          const tempBoundary = document.getElementById('temperature-notches').getBoundingClientRect();
#          const dragBar = document.getElementById('var1-container').getBoundingClientRect();
#          let lowestX = dragBar.x;
#          let highestX = dragBar.x + dragBar.width + tempBoundary.width;
#
#          const isMobile = !event.clientX && event.touches[0].clientX;
#
#          if (isMobile) {
#              highestX *= 1.3;
#              /*
#                          fetch('http://localhost:3000/post', {
#                              method: 'POST',
#                              headers: {
#                                  "Content-type": "application/json"
#                              },
#                              body: JSON.stringify({ 'y': cursorY, 'lowestX': lowestX })
#                          }); */
#          }
#
#          if (cursorX >= lowestX && cursorX <= highestX
#              && tempBoundary.y <= cursorY
#              && tempBoundary.y + tempBoundary.height >= cursorY) {
#              document.querySelector('#thermometer').style.cursor = 'pointer';
#              if (mouseMove && cursorX) {
#                  changeState(cursorY);
#              }
#          }
#          else {
#              document.querySelector('#thermometer').style.cursor = null;
#          }
#      }
#
#      function degradationMultiplier(selectedCar) {
#          const percentDegradation = 0.023;
#          return (1 - ((new Date().getFullYear() - +selectedCar.Year) * percentDegradation));
#      }
#
#      function updateVariables(indexesTraversed) {
#          const range21Original = EVTool_SETTINGS.isBatteryDegradation ?
#              Math.round(degradationMultiplier(selectedCar) * (selectedCar['21C range (km)-original']) * 10) / 10
#              : selectedCar['21C range (km)-original'];
#          const medianValueNode = document.querySelectorAll('#var3-container text')[1];
#          const medianMetricNode = document.querySelectorAll('#var3-container text')[0];
#          const percentile10ValueNode = document.querySelectorAll('#var2-container text')[1];
#          const percentile10MetricNode = document.querySelectorAll('#var2-container text')[0];
#          const percentile90ValueNode = document.querySelectorAll('#var4-container text')[1];
#          const percentile90MetricNode = document.querySelectorAll('#var4-container text')[0];
#
#          const starValueNode = document.querySelectorAll('#max-range text')[1];
#          const starMetricNode = document.querySelectorAll('#max-range text')[0];
#
#          const metricUnits = [medianMetricNode, percentile10MetricNode, percentile90MetricNode, starMetricNode];
#
#          const selectedBattery = document.querySelector('.BatterySizeSelectContainer select');
#          const batterySizeValue = selectedBattery.options[selectedBattery.selectedIndex].value;
#
#          const currentTemp = EVTool_SETTINGS.isImperial ?
#              Math.round(celciusToFarenheight(selectedTemperatureObj.Temp)) :
#              Math.round(selectedTemperatureObj.Temp);
#          setTemperatureInDragbar(currentTemp);
#
#          metricUnits.forEach(node => EVTool_SETTINGS.isImperial ?
#              node.textContent = 'mi' : node.textContent = 'Km'
#          );
#
#          if (selectedTemperatureObj && batterySizeValue) {
#
#              if (EVTool_SETTINGS.optimalTemp - selectedTemperatureObj.Temp < 1.2
#                  && EVTool_SETTINGS.optimalTemp - selectedTemperatureObj.Temp > 0) {
#                  document.getElementById('star').setAttribute('fill', 'gold');
#                  document.getElementById('baseline-21-degrees').setAttribute('fill', 'gold');
#                  document.getElementById('baseline-21-degrees').setAttribute('font-weight', 'bold');
#              } else {
#                  document.getElementById('star').setAttribute('fill', 'none');
#                  document.getElementById('baseline-21-degrees').setAttribute('fill', '#66788c');
#                  document.getElementById('baseline-21-degrees').setAttribute('font-weight', null);
#              }
#
#              if (selectedCar.Make === 'Tesla') {
#                  const toMph = EVTool_SETTINGS.isImperial ? kmToMiles : 1;
#                  medianValueNode.textContent = Math.round(range21Original *
#                      selectedTemperatureObj['Range factor relative 21C - overall - Tesla'] * toMph);
#                  percentile90ValueNode.textContent = Math.round(range21Original *
#                      selectedTemperatureObj['Range factor relative 21C - 90th - Tesla'] * toMph);
#                  percentile10ValueNode.textContent = Math.round(range21Original *
#                      selectedTemperatureObj['Range factor relative 21C - 10th - Tesla'] * toMph);
#                  starValueNode.textContent = Math.round(range21Original *
#                      evTempData[getTempToDataIndex(EVTool_SETTINGS.optimalTemp)]['Range factor relative 21C - 90th - Tesla'] * toMph);
#
#                  const carTravelContainerWidth = percentile90ValueNode.getBoundingClientRect().x
#                      - percentile10ValueNode.getBoundingClientRect().x;
#                  const centerPercentileKM = (+percentile90ValueNode.textContent + +percentile10ValueNode.textContent) / 2;
#
#                  const pixelPerKM = centerPercentileKM / carTravelContainerWidth;
#
#                  const midpointOffset = medianValueNode.textContent - centerPercentileKM;
#
#                  moveCar(midpointOffset, pixelPerKM);
#              }
#              else {
#                  const toMph = EVTool_SETTINGS.isImperial ? kmToMiles : 1;
#                  medianValueNode.textContent = Math.round(range21Original *
#                      selectedTemperatureObj['Range factor relative 21C - overall - Not Tesla'] * toMph);
#                  percentile90ValueNode.textContent = Math.round(range21Original *
#                      selectedTemperatureObj['Range factor relative 21C - 90th - Not Tesla'] * toMph);
#                  percentile10ValueNode.textContent = Math.round(range21Original *
#                      selectedTemperatureObj['Range factor relative 21C - 10th - Not Tesla'] * toMph);
#                  starValueNode.textContent = Math.round(range21Original * evTempData[getTempToDataIndex(EVTool_SETTINGS.optimalTemp)]['Range factor relative 21C - 90th - Not Tesla'] * toMph);
#
#                  const carTravelContainerWidth = percentile90ValueNode.getBoundingClientRect().x
#                      - percentile10ValueNode.getBoundingClientRect().x;
#                  const centerPercentileKM = (+percentile90ValueNode.textContent + +percentile10ValueNode.textContent) / 2;
#
#                  const pixelPerKM = centerPercentileKM / carTravelContainerWidth;
#
#                  const midpointOffset = medianValueNode.textContent - centerPercentileKM;
#
#                  moveCar(midpointOffset, pixelPerKM);
#              }
#          }
#      }
#
#      function setTemperatureInDragbar(temp) {
#          temp = temp + '';
#          const offset = (temp.length - 1) * 6;
#          const tempValue = document.querySelectorAll('#var1-container text')[0];
#          tempValue.setAttribute('transform', `translate(${EVTool_SETTINGS.dragBarTextDefaultX - offset}, ${EVTool_SETTINGS.dragBarTextY} )`);
#          tempValue.textContent = temp;
#      }
#
#      function fillDefaultVariables() {
#          setTemperatureInDragbar(EVTool_SETTINGS.defaultTemp);
#
#          //  Have to calcualte this as car moves
#          const star = document.getElementById("star");
#          const percentile10XOriginal = document.getElementById('Percentile90Label').getBoundingClientRect().x
#              + document.getElementById('Percentile90Label').getBoundingClientRect().width;
#          const starX = star.getBoundingClientRect().x - star.getBoundingClientRect().width / 2;
#          optimalWidth = +document.getElementById('var4-bar').getAttribute('width');
#          starOffSet = starX - percentile10XOriginal;
#
#      }
#
#      function fillMakeModelOptions(evCarData) {
#          for (let car in evCarData) {
#              const makeModelOption = document.createElement('option');
#              makeModelOption.value = car;
#              makeModelOption.innerHTML = car;
#              document.querySelector('.MakeModelSelectContainer select').appendChild(makeModelOption);
#          }
#      }
#
#      function resetSelection(name, className) {
#          const selected = document.querySelector(`.${className} select`);
#          selected.innerHTML = '';
#          const defaultOption = document.createElement('option');
#          defaultOption.disabled = true;
#          defaultOption.selected = true;
#          defaultOption.value = '';
#          defaultOption.innerHTML = name;
#          selected.appendChild(defaultOption);
#      }
#
#      function changeState(mousePosition) {
#          const pixelsMoved = mousePosition - dragBarCenterY;
#          const indexesTraversed = Math.round(pixelsMoved / tempHeightPerIncrement);
#
#          if (evTempData[getTempToDataIndex(EVTool_SETTINGS.defaultTemp) - indexesTraversed] &&
#              (selectedCar.Make !== 'Tesla' || (evTempData[getTempToDataIndex(EVTool_SETTINGS.defaultTemp) - indexesTraversed]
#                  && (evTempData[getTempToDataIndex(EVTool_SETTINGS.defaultTemp) - indexesTraversed].Temp
#                      < EVTool_SETTINGS.teslaHighestTemp)
#                  && (evTempData[getTempToDataIndex(EVTool_SETTINGS.defaultTemp) - indexesTraversed].Temp
#                      > EVTool_SETTINGS.teslaLowestTemp)))) {
#              document.getElementById('DragBar').style.transform = `translate(0,${pixelsMoved}px) `;
#              selectedTemperatureObj = evTempData[getTempToDataIndex(EVTool_SETTINGS.defaultTemp) - indexesTraversed];
#
#              if (document.querySelector('.BatterySizeSelectContainer select').selectedIndex) {
#                  updateRangeWidth();
#                  updateVariables(indexesTraversed);
#              }
#          }
#      }
#
#      function moveCar(midpointOffset, pixelPerKM) {
#          const carLabelsToMove =
#              [document.getElementById('Percentile10Label'),
#              document.getElementById('Percentile90Label'),
#              document.getElementById('Percentile10Red'),
#              document.getElementById('Percentile90Green')];
#
#          const car = document.getElementById('Car');
#
#          const offSetPercent = selectedCar.Make === 'Tesla' ? selectedTemperatureObj['Range factor relative 21C - 90th - Tesla']
#              : selectedTemperatureObj['Range factor relative 21C - 90th - Not Tesla'];
#          carLabelsToMove.forEach(node => node.style.transform = `translate(${-starOffSet * offSetPercent}px, 0)`);
#          car.style.transform = `translate(${-(starOffSet * offSetPercent)}px, 0)`;
#          //TODO: Very small impact, but more accurate middle, since it's not exactly in the middle
#          //car.style.transform = `translate(${(midpointOffset * pixelPerKM) - (starOffSet * offSetPercent)}px, 0)`;
#      }
#
#      function updatePercentileWidth() {
#          const star = document.getElementById("star");
#          const percentile10XOriginal = document.getElementById('Percentile90Label').getBoundingClientRect().x
#              + document.getElementById('Percentile90Label').getBoundingClientRect().width;
#          const starX = star.getBoundingClientRect().x - star.getBoundingClientRect().width / 2;
#          starOffSet = starX - percentile10XOriginal;
#
#          starOffSet
#          const carLabelsToMove =
#              [document.getElementById('Percentile10Label'),
#              document.getElementById('Percentile90Label'),
#              document.getElementById('Percentile10Red'),
#              document.getElementById('Percentile90Green')];
#      }
#
#      onRender();
#  </script>]

# %%
# get and clean up the car data (strip unnecessary string)
ev_data = scripts[0].string.lstrip("\r\n    const EV_DATA = ")
# load as a json object
json_obj = json.loads(ev_data)

# %%
# it contains data for these EVs
json_obj.keys()
# Out:
# dict_keys(['Bmw i3 ', 'Chevrolet Bolt ', 'Chevrolet Spark ', 'Coda Sedan ', 'Fiat 500e ', 'Ford Focus ', 'Honda Fit ', 'Hyundai Ioniq Electric ', 'Hyundai Kona ', 'Kia Soul ', 'Mercedes-Benz B-Class ', 'Mitsubishi iMiEV ', 'Nissan eNV200 ', 'Nissan Leaf ', 'Renault Zoe ', 'Renault Kangoo Z.E. ', 'Smart For Two Electric Drive ', 'Tesla Model S', 'Tesla Model 3 ', 'Think City ', 'Toyota RAV4', 'Volkswagen e-Golf '])

# %%
# take a look at the data
json_obj['Tesla Model 3 ']
# Out:
# {'2018': {'54': {'MMY': 'Tesla Model 3 2018',
#    'Make': 'Tesla',
#    'Model': 'Model 3 ',
#    'Trim details': '',
#    'Year': '2018',
#    'Median peak fuel efficieny (21C) wh/km': '157.6561135',
#    'Battery size (kwh) - at purchase': '54',
#    '21C range (km)-original': '342.5176404',
#    'Powertrain': 'EV'}},
#  '2019': {'54': {'MMY': 'Tesla Model 3 2019',
#    'Make': 'Tesla',
#    'Model': 'Model 3 ',
#    'Trim details': '',
#    'Year': '2019',
#    'Median peak fuel efficieny (21C) wh/km': '152.44',
#    'Battery size (kwh) - at purchase': '54',
#    '21C range (km)-original': '354',
#    'Powertrain': 'EV'}}}

# %%
# do the same thing for scale factors
factor_data = source.find_all("script")[2].string
factor_data = factor_data.lstrip("\r\n    const TEMP_DATA = ")
factors = json.loads(factor_data)

# %%
# take a look at what the data look like so that we can write codes to extract useful data
factors[0]
# Out:
# {'Temp': '-23',
#  'Range factor relative 21C - overall - Not Tesla': '0.423087273',
#  'Range factor relative 21C - 90th - Not Tesla': '0.542401766',
#  'Range factor relative 21C - 10th - Not Tesla': '0.293100333',
#  'Range factor relative 21C - overall - Tesla': '#N/A',
#  'Range factor relative 21C - 90th - Tesla': '#N/A',
#  'Range factor relative 21C - 10th - Tesla': '#N/A'}

# %%
temps = np.zeros(len(factors))
tesla_factor = np.zeros(len(factors))
not_tesla_factor = np.zeros(len(factors))

# %%
for i, f in zip(range(len(factors)), factors):
    # temperature
    temps[i] = f["Temp"]
    # factor for non-Tesla EVs
    not_tesla_factor[i] = f["Range factor relative 21C - overall - Not Tesla"]
    # factor for Tesla EVs
    if f["Range factor relative 21C - overall - Tesla"] == '#N/A':
        tesla_factor[i] = np.nan
    else:
        tesla_factor[i] = f["Range factor relative 21C - overall - Tesla"]

# %%
# plot the scale factors vs temperature plot
# NOTE: scale factor*100-100 is equivalent to range loss
plt.figure(figsize=(6, 2), dpi=600)
plt.plot(temps, not_tesla_factor*100-100, c='r', label="Non-Tesla")
plt.plot(temps, tesla_factor*100-100, c='b', label="Tesla")
plt.xlim((-25, 45))
plt.ylim((-70, 10))
plt.xlabel("Temperature (°C)")
plt.ylabel("Range Loss")

plt.legend()

# %%
# save scale factors to a csv file
df = pd.DataFrame([temps, tesla_factor, not_tesla_factor]).transpose()
df.columns = ["Temperature", "Tesla Factors", "Not Tesla Factors"]
df.to_csv("./data/scale_factors.csv",index=False)
